# %%
import utils
import importlib
importlib.reload(utils)

utils.unzip_data("NRC-Emotion-Lexicon.zip")
# Out:
# unzipped to data

# %%
import sentiment_tracker

# %%
# !python sentiment_tracker.py
# Out:
# Tracking sentiment shifts over time
#
#  Anomaly Detected for User 782 at 2023-10-01T10:45:00Z
# Message: I’d like to read the daily stories! They used to lift my spirits.
# Sentiment Score: 0.00, Lexicon Score: 1, Combined: 0.30
# Detected by: rule_based
#
#
#  Anomaly Detected for User 1 at 2023-10-01T10:50:00Z
# Message: Great choice! You can find them in the 'Stories' section. Just tap on that menu. Let me know if you need help finding it.
# Sentiment Score: 1.00, Lexicon Score: 1, Combined: 1.00
# Detected by: rule_based
#
#
#  Anomaly Detected for User 1 at 2023-10-02T11:20:00Z
# Message: I’m sorry to hear that, ChattyPenguin. It’s tough to feel unwell. Would you like to share more about what’s bothering you?
# Sentiment Score: -0.13, Lexicon Score: 0, Combined: -0.09
# Detected by: rule_based
#
#
#  Anomaly Detected for User 1 at 2023-10-02T11:30:00Z
# ...
